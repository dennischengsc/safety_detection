# %%
import cv2
import matplotlib.pyplot as plt
from ultralytics import YOLO
from ultralytics.models.yolo.detect.predict import DetectionPredictor
from pydub import AudioSegment
from pydub.playback import play

model = YOLO('best.pt')

# Open the camera
camera = cv2.VideoCapture(0)
img_counter = 0


ret, frame = camera.read()

results = model.predict(frame)
result = results[0]
box = result.boxes[0]
class_id = result.names[box.cls[0].item()]
class_id
# Out:
# 0: 384x640 3 NO-Hardhats, 1 NO-Mask, 2 Persons, 48.2ms
# Speed: 2.5ms preprocess, 48.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 18
#      15 ret, frame = camera.read()
#      17 results = model.predict(frame)
# ---> 18 result = results[1]
#      19 box = result.boxes[0]
#      20 class_id = result.names[box.cls[0].item()]
#
# IndexError: list index out of range

# %%
plt.imshow(frame)
